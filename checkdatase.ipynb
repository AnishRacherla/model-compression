# %%
import pandas as pd

df = pd.read_parquet("wmt_stage6_final_36k_en_zh.parquet")
print(df.head())
print(df.columns)
print(df.info())
print(df.dtypes)
# Out:
#                 target                                           source  \
# 0     Charlie，我需要你的帮助。                       Charlie, I need your help.
# 1             我爱我的新工作.                               I love my new job.
# 2  最重要的是, 它快捷, 容易而且免费.  Most importantly, it was quick, easy, and free.
# 3             我需要你的帮助。                                I need your help.
# 4           我真的需要你的帮助。                         I really need your help.
#
#    similarity_score  perplexity  comet_score
# 0          0.987136   15.111453     0.964781
# 1          0.948330   40.891113     0.937305
# 2          0.876190   16.864328     0.925703
# 3          0.985844   11.639119     0.924632
# 4          0.974189   15.400594     0.923124
# Index(['target', 'source', 'similarity_score', 'perplexity', 'comet_score'], dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36513 entries, 0 to 36512
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ...
